# %% [markdown]
# <a href="https://colab.research.google.com/github/kysssib/DataScience/blob/main/Week7_Midterm_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
strVal = 'data science'
nVal = 12345
fVal = 1.2
lVal = ['data', 'science']
dVal = {'lecture' : 'data science'}
bVal = True

# %%
# 기본적인 주석
''' 
주석
'''
# Out:
# ' \n주석\n'

# %%
strVal
# Out:
# 'data science'

# %%
nVal
# Out:
# 12345

# %%
fVal
# Out:
# 1.2

# %%
lVal
# Out:
# ['data', 'science']

# %%
dVal
# Out:
# {'lecture': 'data science'}

# %%
bVal
# Out:
# True

# %%
print('strVal : ', strVal)
print('nVal : ', nVal)
print('fVal : ', fVal)
print('lVal : ', lVal)
print('dVal : ', dVal)
print('bVal : ', bVal)
# Out:
# strVal :  data science
# nVal :  12345
# fVal :  1.2
# lVal :  ['data', 'science']
# dVal :  {'lecture': 'data science'}
# bVal :  True

# %%
print('strVal : ', type(strVal))
print('nVal : ', type(nVal))
print('fVal : ', type(fVal))
print('lVal : ', type(lVal))
print('dVal : ', type(dVal))
print('bVal : ', type(bVal))
# Out:
# strVal :  <class 'str'>
# nVal :  <class 'int'>
# fVal :  <class 'float'>
# lVal :  <class 'list'>
# dVal :  <class 'dict'>
# bVal :  <class 'bool'>

# %%
nVal = 16
fVal = 3.14

# %%
print('10진수 표현 : ', nVal)
print('2진수 표현 : ', bin(nVal))
print('8진수 표현 : ', oct(nVal))
print('16진수 표현 : ', hex(nVal))
# Out:
# 10진수 표현 :  16
# 2진수 표현 :  0b10000
# 8진수 표현 :  0o20
# 16진수 표현 :  0x10

# %%
btVal = True
bfVal = False

# %%
btVal = TRUE    # 오류
bfVal = FALSE   # 오류
btVal = true    # 오류
bfVal = false   # 오류

# %%
10 == 11
# Out:
# False

# %%
10 != 11
# Out:
# True

# %%
10 >= 11

# %%
10 <= 11

# %%
10 > 11

# %%
10 < 11

# %%
nBig = 100
nSmall = 10

# %%
print(nBig == nSmall)
print(nBig != nSmall)
print(nBig >= nSmall)
print(nBig <= nSmall)
print(nBig > nSmall)
print(nBig < nSmall)
# Out:
# False
# True
# True
# False
# True
# False

# %%
print(nBig =< nSmall)     # 오류
print(nBig => nSmall)     # 오류

# %%
strData = 'data'
strSci = "Science"

# %%
strLecture = strData + strSci
strLecture
# Out:
# 'dataScience'

# %%
strLecture = strData +" "+ strSci
strLecture
# Out:
# 'data Science'

# %%
strLecture.split()
lSeperate = strLecture.split()

# %%
type(lSeperate)
# Out:
# list

# %%
strHello = "안녕하세요. 반갑습니다."
strHello.find("반갑")
# Out:
# 7

# %%
strHello.find("hello")
# Out:
# -1

# %%
"반갑" in strHello
# Out:
# True

# %%
strHello.replace('.', '?')
# Out:
# '안녕하세요? 반갑습니다?'

# %%
strHello.replace('.', '?')
strHello.replace("하세요", "하셔유")
# Out:
# '안녕하셔유. 반갑습니다.'

# %%
strHello
# Out:
# '안녕하세요. 반갑습니다.'

# %%
strNewHello = strHello.replace('.', '?')
strNewHello = strNewHello.replace("하세요", "하셔유")
strNewHello
# Out:
# '안녕하셔유? 반갑습니다?'

# %%
strHello.strip('반갑습니다.')
# Out:
# '안녕하세요. '

# %%
strHello
# Out:
# '안녕하세요. 반갑습니다.'

# %%
lnData = [1,2,3,4,5]
print(lnData)
print('type : ', type(lnData))
# Out:
# [1, 2, 3, 4, 5]
# type :  <class 'list'>

# %%
print(lnData[0])
print(lnData[3])
# Out:
# 1
# 4

# %%
lnData[0] = lnData[4]
print(lnData)
# Out:
# [5, 2, 3, 4, 5]

# %%
print(lnData[2:4])
# Out:
# [3, 4]

# %%
lnData = [1,2,3,4,5]
lstrData=['a', 'b', 'c']

# 병합
lnData + lstrData
# Out:
# [1, 2, 3, 4, 5, 'a', 'b', 'c']

# %%
lnData.append(10)
lnData
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
lnData.insert(0, 'python')
lnData
# Out:
# ['python', 1, 2, 3, 4, 5, 10]

# %%
lnData.remove('python')
lnData
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
del lnData[5]
lnData
# Out:
# [1, 2, 3, 4, 5]

# %%
lnData
# Out:
# [1, 2, 3, 4, 5]

# %%
lnData.pop(0)
lnData
# Out:
# [2, 3, 4, 5]

# %%
lnData.pop()
lnData
# Out:
# [2, 3, 4]

# %%
lnData.clear()
lnData
# Out:
# []

# %%
tVal = ("사과", "딸기", "바나나", "토마토", "키위")

print(tVal)
print(type(tVal))
# Out:
# ('사과', '딸기', '바나나', '토마토', '키위')
# <class 'tuple'>

# %%
tVal[0] = "포도"    #오류

# %%
tData = ( 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)
tData.count(1)
# Out:
# 3

# %%
len(tVal)
# Out:
# 5

# %%
len(tData)
# Out:
# 11

# %%
print(tData[2:5])
# Out:
# (3, 1, 2)

# %%
tTuple = tVal+ tData
print(tTuple)
# Out:
# ('사과', '딸기', '바나나', '토마토', '키위', 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
tData * 2
# Out:
# (1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7, 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
tData
# Out:
# (1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
tData2 = tData * 2
print(tData2)
# Out:
# (1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7, 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
print("tVal memory = ", hex(id(tVal)))
tVal = tVal * 2
print("tVal memory = ", hex(id(tVal)))
print(tVal)
# Out:
# tVal memory =  0x7fafd6aaa410
# tVal memory =  0x7fafd7399dd0
# ('사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위')

# %%
print("tVal memory = ", hex(id(tVal)))
tVal = tVal + tVal
print("tVal memory = ", hex(id(tVal)))
print(tVal)
# Out:
# tVal memory =  0x7fafd7399dd0
# tVal memory =  0x7fafd6c12910
# ('사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위')

# %%
sVal = {1, 2, 3, 4, 5}
print(sVal)
print(type(sVal))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
sVal[1:2]    #오류

# %%
sVal.add(100)
print(sVal)
# Out:
# {1, 2, 3, 4, 5, 100}

# %%
sVal.update([200, 300])
print(sVal)
# Out:
# {1, 2, 3, 4, 5, 100, 200, 300}

# %%
sVal.remove(200)
print(sVal)
# Out:
# {1, 2, 3, 4, 5, 100, 300}

# %%
sVal.clear()
print(sVal)
# Out:
# set()

# %%
sVal = {100, 200, 300, 400, 500}
sData = {"a", "b", "c", "c", 100, 300}
print(sVal)
print(sData)
# Out:
# {100, 200, 300, 400, 500}
# {100, 'a', 300, 'b', 'c'}

# %%
sVal.intersection(sData)
# Out:
# {100, 300}

# %%
sVal.difference(sData)
# Out:
# {200, 400, 500}

# %%
sVal - sData
# Out:
# {200, 400, 500}

# %%
sVal.union(sData)
# Out:
# {100, 200, 300, 400, 500, 'a', 'b', 'c'}

# %%
sVal + sData   #오류

# %%
sVal.symmetric_difference(sData)
# Out:
# {200, 400, 500, 'a', 'b', 'c'}

# %%
dVal = {
    'name' : '이컴공',
    'email' : 'computer@hoseo.edu',
    'address' : '충남 아산시'
}
print(dVal)
print(type(dVal))
# Out:
# {'name': '이컴공', 'email': 'computer@hoseo.edu', 'address': '충남 아산시'}
# <class 'dict'>

# %%
dData = {
    "사과" : 300, 
    "포도" : 200, 
    "배" : 500,
    "키위" : 100
}

# %%
print(dData["배"])
# Out:
# 500

# %%
dData.get("배")
# Out:
# 500

# %%
dData["딸기"] = 100
print(dData)
# Out:
# {'사과': 300, '포도': 200, '배': 500, '키위': 100, '딸기': 100}

# %%
dData.pop("사과")
# Out:
# 300

# %%
dData
# Out:
# {'포도': 200, '배': 500, '키위': 100, '딸기': 100}

# %%
dData.pop()    #오류

# %%
sorted(dData)
# Out:
# ['딸기', '배', '키위', '포도']

# %%
sorted(dData.values())
# Out:
# [100, 100, 200, 500]

# %%
dData
# Out:
# {'포도': 200, '배': 500, '키위': 100, '딸기': 100}

# %%
def f(x):
  return x + 10

# %%
f(2)
# Out:
# 12

# %%
'''=============================================================================='''

# %%
strText = input("아무 문장이나 입력하세요 : ")
print(strText)
# Out:
# 아무 문장이나 입력하세요 : hello world!
# hello world!

# %%
flVal = [1.0, 2.0, 3.14, 4.2, 5.1]
arVal = [flVal, flVal, flVal]
arVal
# Out:
# [[1.0, 2.0, 3.14, 4.2, 5.1],
#  [1.0, 2.0, 3.14, 4.2, 5.1],
#  [1.0, 2.0, 3.14, 4.2, 5.1]]

# %%
arVal[0]
# Out:
# [1.0, 2.0, 3.14, 4.2, 5.1]

# %%
arVal[1]
# Out:
# [1.0, 2.0, 3.14, 4.2, 5.1]

# %%
arVal[1][2]
# Out:
# 3.14

# %%
arVal[0] = 'python'
arVal
# Out:
# ['python', [1.0, 2.0, 3.14, 4.2, 5.1], [1.0, 2.0, 3.14, 4.2, 5.1]]

# %%
arVal[0][2]
# Out:
# 't'

# %%
arVal[0] = 'python programming'
arVal
# Out:
# ['python programming', [1.0, 2.0, 3.14, 4.2, 5.1], [1.0, 2.0, 3.14, 4.2, 5.1]]

# %%
import numpy as np
arData = np.array([1.0, 2.0, 3.14, 4.2, 5.1])
arData
# Out:
# array([1.  , 2.  , 3.14, 4.2 , 5.1 ])

# %%
arData.sum()
# Out:
# 15.44

# %%
arVal.sum()    #오류

# %%
print(type(arVal))
print(type(arData))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
arData.std()
# Out:
# 1.4717934637713266

# %%
arData.cumsum()
# Out:
# array([ 1.  ,  3.  ,  6.14, 10.34, 15.44])

# %%
arData * 2
# Out:
# array([ 2.  ,  4.  ,  6.28,  8.4 , 10.2 ])

# %%
arData ** 2
# Out:
# array([ 1.    ,  4.    ,  9.8596, 17.64  , 26.01  ])

# %%
np.sqrt(arData)
# Out:
# array([1.        , 1.41421356, 1.77200451, 2.04939015, 2.25831796])

# %%
arVal = np.array([arData, arData ** 2])
arVal
# Out:
# array([[ 1.    ,  2.    ,  3.14  ,  4.2   ,  5.1   ],
#        [ 1.    ,  4.    ,  9.8596, 17.64  , 26.01  ]])

# %%
arVal.sum(axis=0)
# Out:
# array([ 2.    ,  6.    , 12.9996, 21.84  , 31.11  ])

# %%
arVal.sum(axis=1)
# Out:
# array([15.44  , 58.5096])

# %%
np.array([[0,0,0],[0,0,0]])
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
arZero = np.zeros((2,3), dtype = 'i') 
arZero
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]], dtype=int32)

# %%
import pandas as pd

pandas_series = pd.Series([30, 20, 10], index = ['국어', '영어', '수학'])
print(type(pandas_series))
pandas_series
# Out:
# <class 'pandas.core.series.Series'>
# 국어    30
# 영어    20
# 수학    10
# dtype: int64

# %%
pandas_series[1:]
# Out:
# 영어    20
# 수학    10
# dtype: int64

# %%
pandas_series[0]
# Out:
# 30

# %%
pandas_series[0][1]     #오류

# %%
df = pd.DataFrame([30,20,10], columns = ['score'], index = ['국어', '영어', '수학'])
df
# Out:
#     score
# 국어     30
# 영어     20
# 수학     10

# %%
df.index
# Out:
# Index(['국어', '영어', '수학'], dtype='object')

# %%
df.columns
# Out:
# Index(['score'], dtype='object')

# %%
df.loc['국어']
# Out:
# score    30
# Name: 국어, dtype: int64

# %%
df.sum()
# Out:
# score    60
# dtype: int64

# %%
df.score ** 2
# Out:
# 국어    900
# 영어    400
# 수학    100
# Name: score, dtype: int64

# %%
df['score2'] = (50, 50, 50)
df
# Out:
#     score  score2
# 국어     30      50
# 영어     20      50
# 수학     10      50

# %%
df['score2'] = pd.DataFrame([90,90,90], index = ['국어', '영어', '수학'])
df
# Out:
#     score  score2
# 국어     30      90
# 영어     20      90
# 수학     10      90

# %%
del df['score']

# %%
df['score2'] = (90, 90, 90, 100)    #오류

# %%
df['score2'] = pd.DataFrame([90, 90, 90, 100], index = ['국어', '영어', '수학', '윤리'])
df
# Out:
#     score2
# 국어      90
# 영어      90
# 수학      90

# %%
df1 = pd.DataFrame([1, 2, 3], columns = ['A'])
df2 = pd.DataFrame([10, 11, 12, 13], columns = ['B'])

df = df1.join(df2, how='outer')
df
# Out:
#      A   B
# 0  1.0  10
# 1  2.0  11
# 2  3.0  12
# 3  NaN  13

# %%
df_inner = df1.join(df2, how = 'inner')
df_inner
# Out:
#    A   B
# 0  1  10
# 1  2  11
# 2  3  12

# %%
df = pd.DataFrame(np.random.randn(5,5))
df.columns = ['A', 'B', 'C', 'D', 'E']

df
# Out:
#           A         B         C         D         E
# 0  1.658290  0.378364 -1.518845  1.037690 -0.631374
# 1  0.134000 -0.177640 -2.174931 -0.258808 -0.603544
# 2 -0.889410 -0.256751  1.084697 -1.000573  1.539013
# 3  1.727135 -0.223869  1.002960  0.336591 -0.970543
# 4 -1.318392 -1.418322  0.141641  0.155984  0.481164

# %%
df.max()
# Out:
# A    1.727135
# B    0.378364
# C    1.084697
# D    1.037690
# E    1.539013
# dtype: float64

# %%
df.min()
# Out:
# A   -1.318392
# B   -1.418322
# C   -2.174931
# D   -1.000573
# E   -0.970543
# dtype: float64

# %%
df.mean()
# Out:
# A    0.262324
# B   -0.339644
# C   -0.292896
# D    0.054177
# E   -0.037057
# dtype: float64

# %%
df.std()
# Out:
# A    1.408546
# B    0.656811
# C    1.484152
# D    0.752974
# E    1.036589
# dtype: float64

# %%
df.cumsum()
# Out:
#           A         B         C         D         E
# 0  1.658290  0.378364 -1.518845  1.037690 -0.631374
# 1  1.792290  0.200723 -3.693776  0.778882 -1.234918
# 2  0.902879 -0.056028 -2.609079 -0.221691  0.304095
# 3  2.630014 -0.279897 -1.606119  0.114901 -0.666447
# 4  1.311622 -1.698218 -1.464478  0.270885 -0.185284

# %%
df.describe()
# Out:
#               A         B         C         D         E
# count  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   0.262324 -0.339644 -0.292896  0.054177 -0.037057
# std    1.408546  0.656811  1.484152  0.752974  1.036589
# min   -1.318392 -1.418322 -2.174931 -1.000573 -0.970543
# 25%   -0.889410 -0.256751 -1.518845 -0.258808 -0.631374
# 50%    0.134000 -0.223869  0.141641  0.155984 -0.603544
# 75%    1.658290 -0.177640  1.002960  0.336591  0.481164
# max    1.727135  0.378364  1.084697  1.037690  1.539013

# %%
df['division'] = ['X', 'Y', 'X', 'Y', 'Z']
df
# Out:
#           A         B         C         D         E division
# 0  1.658290  0.378364 -1.518845  1.037690 -0.631374        X
# 1  0.134000 -0.177640 -2.174931 -0.258808 -0.603544        Y
# 2 -0.889410 -0.256751  1.084697 -1.000573  1.539013        X
# 3  1.727135 -0.223869  1.002960  0.336591 -0.970543        Y
# 4 -1.318392 -1.418322  0.141641  0.155984  0.481164        Z

# %%
df.groupby(['division']).mean()
# Out:
#                  A         B         C         D         E
# division
# X         0.384440  0.060806 -0.217074  0.018558  0.453820
# Y         0.930567 -0.200755 -0.585986  0.038892 -0.787043
# Z        -1.318392 -1.418322  0.141641  0.155984  0.481164

# %%
'''=============================================================================='''

# %%
import pandas as pd

sr = pd.Series([100, 200, 300, 400])
sr.index = ['A', 'B', 'O', 'AB']
sr
# Out:
# A     100
# B     200
# O     300
# AB    400
# dtype: int64

# %%
sr1 = pd.Series([10, 20, 30])
sr1
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.DataFrame({'키':[170, 180, 175], '몸무게':[65, 78, 70]})
df.index = ['스파이더맨', '닥터스트레인지', '아이언맨']
df
# Out:
#            키  몸무게
# 스파이더맨    170   65
# 닥터스트레인지  180   78
# 아이언맨     175   70

# %%
df = pd.read_csv('scores.csv', encoding = 'cp949')
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.head()
# Out:
#        이름     국어   영어     수학
# 0    tony  100.0   90   95.0
# 1     sam   90.0   80   75.0
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0

# %%
df.tail()
# Out:
#         이름     국어   영어    수학
# 5      tor   70.0   75  65.0
# 6    bruce   80.0   90  55.0
# 7     thor   50.0   60   NaN
# 8  steaven  100.0  100  90.0
# 9    wanda   90.0   95  70.0

# %%
df.sample(3)
# Out:
#        이름    국어   영어     수학
# 7    thor  50.0   60    NaN
# 2  vision  95.0  100  100.0
# 1     sam  90.0   80   75.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      10 non-null     object
#  1   국어      9 non-null      float64
#  2   영어      10 non-null     int64
#  3   수학      9 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
df.shape
# Out:
# (10, 4)

# %%
len(df)
# Out:
# 10

# %%
df.isnull().sum()
# Out:
# 이름    0
# 국어    1
# 영어    0
# 수학    1
# dtype: int64

# %%
df_dropna = df.dropna()
df_dropna
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df_fillna = df.fillna(50)
df_fillna
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott   50.0   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60   50.0
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.describe()
# Out:
#                국어          영어          수학
# count    9.000000   10.000000    9.000000
# mean    86.111111   82.500000   78.888889
# std     16.914819   21.114766   17.638342
# min     50.000000   35.000000   55.000000
# 25%     80.000000   76.250000   65.000000
# 50%     90.000000   90.000000   75.000000
# 75%    100.000000   98.750000   95.000000
# max    100.000000  100.000000  100.000000

# %%
df['국어'].sum()
# Out:
# 775.0

# %%
df.value_counts('영어')
# Out:
# 영어
# 100    3
# 90     2
# 35     1
# 60     1
# 75     1
# 80     1
# 95     1
# dtype: int64

# %%
df['국어']
# Out:
# 0    100.0
# 1     90.0
# 2     95.0
# 3    100.0
# 4      NaN
# 5     70.0
# 6     80.0
# 7     50.0
# 8    100.0
# 9     90.0
# Name: 국어, dtype: float64

# %%
df[['국어', '영어']]
# Out:
#       국어   영어
# 0  100.0   90
# 1   90.0   80
# 2   95.0  100
# 3  100.0  100
# 4    NaN   35
# 5   70.0   75
# 6   80.0   90
# 7   50.0   60
# 8  100.0  100
# 9   90.0   95

# %%
df.loc[1]
# Out:
# 이름     sam
# 국어    90.0
# 영어      80
# 수학    75.0
# Name: 1, dtype: object

# %%
df.loc[[1,2,3]]
# Out:
#        이름     국어   영어     수학
# 1     sam   90.0   80   75.0
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0

# %%
df.iloc[2]
# Out:
# 이름    vision
# 국어      95.0
# 영어       100
# 수학     100.0
# Name: 2, dtype: object

# %%
df.iloc[2:5]
# Out:
#        이름     국어   영어     수학
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0

# %%
df.loc[2:5]
# Out:
#        이름     국어   영어     수학
# 2  vision   95.0  100  100.0
# 3   peter  100.0  100  100.0
# 4   scott    NaN   35   60.0
# 5     tor   70.0   75   65.0

# %%
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.iloc[1,3]
# Out:
# 75.0

# %%
df.iloc[1:3, 1:3]
# Out:
#      국어   영어
# 1  90.0   80
# 2  95.0  100

# %%
'''=============================================================================='''

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 27 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 0s (19.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 123942 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
plt.rc('font', family = 'NanumBarunGothic')
plt.rc('axes', unicode_minus = False)

# %%
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

plt.plot(x,y)
plt.show()

# %%
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

plt.plot(x,y, color = "blue", marker = 'o', linestyle = ':')
plt.title('월별 평균 온도', fontsize=15)
plt.ylabel('온도(도)')
plt.grid(linestyle = ':')
plt.show()

# %%
aVal = np.random.standard_normal(40)
aVal
# Out:
# array([-0.14397215, -0.79747066, -1.65179927, -0.42507386, -1.0940063 ,
#         2.04784646, -1.3217482 , -0.09857288,  0.34532884, -0.40022374,
#        -0.28091659, -0.47077392,  0.95978956,  0.76332622, -1.21529698,
#         2.51176468, -0.9862878 ,  0.90388436, -0.77745573,  0.10288081,
#        -0.71159802,  1.62935842, -0.95628884, -0.68642117,  0.47568877,
#        -2.75667857, -0.97632041, -1.23899954,  0.84919951, -2.24017939,
#         0.48323547,  0.17952336,  0.02400821, -0.91249996,  1.33344181,
#         0.61491589, -0.9425748 , -0.11504659, -0.25415662, -0.69185651])

# %%
type(aVal)
# Out:
# numpy.ndarray

# %%
index = range(len(aVal))
plt.plot(index, aVal)

plt.xlim(0, 20)
plt.ylim(np.min(aVal) -1, np.max(aVal) + 1)
plt.show()

# %%
type(index)
# Out:
# range

# %%
plt.figure(figsize = (7,4))
plt.plot(aVal.cumsum(), 'b', lw = 1.5)
plt.plot(aVal.cumsum(), 'ro')
plt.xlabel('index')
plt.ylabel('aVal')
plt.title('Line Plot')
plt.show()

# %%
value = np.random.standard_normal((30, 2))
value
# Out:
# array([[ 0.10742258, -1.16253014],
#        [ 3.80799138,  1.96488469],
#        [-1.1418199 ,  0.43376202],
#        [ 1.33408802,  1.76628265],
#        [ 1.17119847,  0.45492612],
#        [ 0.33121046, -0.65793183],
#        [ 1.13721758, -0.35469003],
#        [ 0.49411803, -0.04942734],
#        [-0.04876898, -0.86084139],
#        [ 0.99915214,  1.15690462],
#        [-0.7566118 , -0.70110842],
#        [ 1.11050894,  0.24144761],
#        [ 0.6529845 ,  0.03756068],
#        [ 0.63984437, -0.66381962],
#        [ 0.25338144, -1.00409193],
#        [ 1.09804157,  0.46206503],
#        [ 0.67108942, -1.3363834 ],
#        [ 0.533348  , -0.30660457],
#        [ 0.00585588, -0.82113287],
#        [-2.27599219,  0.47350259],
#        [-0.02951723, -0.65362675],
#        [-1.67825411, -0.26355827],
#        [ 0.82618986, -1.6525349 ],
#        [-0.26795275,  0.79699052],
#        [-0.26918525,  1.46234183],
#        [-0.64672326,  1.74424164],
#        [ 0.95472607,  0.14739136],
#        [-0.2425058 ,  1.12385364],
#        [-0.93429379,  1.70200197],
#        [-1.46057813,  0.82507613]])

# %%
value[0]
# Out:
# array([ 0.10742258, -1.16253014])

# %%
plt.figure(figsize=(10,4))
plt.plot(value[:,0], lw = 1.5)
plt.plot(value[:,1], lw = 1.5)
plt.plot(value, 'ro')
plt.grid(True)
# plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('value')
plt.title('Line Plot')
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
# 1
plt.figure(figsize=(10,5))
plt.subplot(211)
plt.plot(value[:,0], lw = 1.5, label = '1st')
plt.plot(value[:,0], 'ro')
plt.grid(True)
plt.legend(loc = 0)
plt.ylabel("value")
plt.title('Line Plot 3')

# 2
plt.subplot(212)
plt.plot(value[:,1], 'g', lw = 1.5, label = '2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
# 1
plt.figure(figsize=(13,5))
plt.subplot(231)
plt.plot(value[:,0], lw = 1.5, label = '1st')
plt.plot(value[:,0], 'co')
plt.grid(True)
plt.legend(loc=0)
plt.ylabel('value')
plt.title('Line Plot 3')

# 2
plt.subplot(232)
plt.plot(value[:,0], 'g-.', lw = 1.5, label = '1st')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')

# 3
plt.subplot(233)
plt.plot(value[:,0], 'g', lw = 1.5, label = '1st')
plt.plot(value[:,0], 'bD')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')

# 4
plt.subplot(234)
plt.plot(value[:,1], '*', lw = 1.5, label = '2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')

# 5
plt.subplot(235)
plt.plot(value[:,1], 'b', lw = 1.5, label = '2nd')
plt.plot(value[:,1], 'ms')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')

# 6
plt.subplot(236)
plt.plot(value[:,1], 'r--', lw = 1.5, label = '2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

plt.bar(x,y)
plt.show()

# %%
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

plt.barh(x,y)
plt.show()

# %%
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

plt.bar(x,y, color = "orange", width = 0.5, edgecolor = 'black', hatch = '/')
plt.title('월별 평균 온도', fontsize=15)
plt.ylabel('온도(도)')
plt.grid(linestyle = ':', axis = 'y')
plt.show()

# %%
import pandas as pd

df = pd.read_csv('scores.csv', encoding = 'cp949')
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    peter  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
x = df['이름']
y_kor = df['국어']

plt.bar(x, y_kor)
plt.show()

# %%
x = df['이름']
y_kor = df['국어']
y_eng = df['영어']

plt.bar(x, y_kor, width = -0.4, align = 'edge', label = '국어')
plt.bar(x, y_eng, width = 0.4, align = 'edge', label = '영어')
plt.title('국어/영어 점수 비교', fontsize = 15)
plt.ylabel('점수')

plt.legend() 
plt.show()

# %%
value = np.random.standard_normal((500,2))
plt.plot(value[:,0], value[:,1], 'ro')
plt.grid(False)
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 1')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 1')

# %%
plt.figure(figsize = (7,5))
plt.scatter(value[:,0], value[:,1], marker='o')
plt.grid(True)
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 2')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 2')

# %%
color = np.random.randint(0,10,len(value))

plt.figure(figsize = (10,5))
plt.scatter(value[:,0], value[:,1], c = color, marker = 'o')
plt.colorbar()
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 3')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 3')

# %%
import seaborn as sns
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
x = df['total_bill']
y = df['tip']

sns.scatterplot(x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(x = "day", y = "tip", hue = "sex", data = df, palette = "muted")

# %%
'''=============================================================================='''

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline    

iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.pairplot(iris)
plt.title("Iris Data Analysis")
# Out:
# Text(0.5, 1.0, 'Iris Data Analysis')

# %%
sns.pairplot(iris, hue = "species", diag_kind = 'kde')

# %%
sns.boxplot(x = 'species', y = "petal_length", data = iris)

# %%
sns.boxplot(x = 'species', y = "petal_width", data = iris)

# %%
iris.boxplot(by = "species", figsize = (16,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f52c008a310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f52c00a7150>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f52c0155b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f52c0013310>]],
#       dtype=object)

# %%
'''=============================================================================='''
